# %%
# Start here

print("Welcome to my Github! Here you can find many machine learning and deep learning projects to start your journey.")
# Out:
# Welcome to my Github! Here you can find many machine learning and deep learning projects to start your journey.

# %%
print("All the best!")
# Out:
# All the best!
